# %%
import pandas as pd
from player_class import player

# %%
df = pd.read_csv("rnfile.csv")

# %%
df
# Out:
#      Unnamed: 0   Rk     Age        Date   Tm Unnamed: 4  Opp Unnamed: 6  PTS  \
# 0             0    1  25-353  2021-02-06  DEN          @  SAC          L   50
# 1             1    2  26-334  2022-01-19  DEN        NaN  LAC          W   49
# 2             2    3  25-347  2021-01-31  DEN        NaN  UTA          W   47
# 3             3    4  24-321  2020-01-06  DEN          @  ATL          W   47
# 4             4    5  26-059  2021-04-19  DEN        NaN  MEM          W   47
# ..          ...  ...     ...         ...  ...        ...  ...        ...  ...
# 500         500  501  20-317  2016-01-02  DEN          @  GSW          L    0
# 501         501  502  21-000  2016-02-19  DEN          @  SAC          L    0
# 502         502  503  21-022  2016-03-12  DEN        NaN  WAS          W    0
# 503         503  504  21-268  2016-11-13  DEN          @  POR          L    0
# 504         504  505  22-244  2017-10-21  DEN        NaN  SAC          W    0
#
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df
# Out:
#       Rk     Age        Date   Tm Unnamed: 4  Opp Unnamed: 6  PTS  GS  MP  \
# 0      1  25-353  2021-02-06  DEN          @  SAC          L   50   1  41
# 1      2  26-334  2022-01-19  DEN        NaN  LAC          W   49   1  41
# 2      3  25-347  2021-01-31  DEN        NaN  UTA          W   47   1  37
# 3      4  24-321  2020-01-06  DEN          @  ATL          W   47   1  37
# 4      5  26-059  2021-04-19  DEN        NaN  MEM          W   47   1  45
# ..   ...     ...         ...  ...        ...  ...        ...  ...  ..  ..
# 500  501  20-317  2016-01-02  DEN          @  GSW          L    0   1   5
# 501  502  21-000  2016-02-19  DEN          @  SAC          L    0   1   4
# 502  503  21-022  2016-03-12  DEN        NaN  WAS          W    0   1  17
# 503  504  21-268  2016-11-13  DEN          @  POR          L    0   0  26
# 504  505  22-244  2017-10-21  DEN        NaN  SAC          W    0   1  31
#
#      ...  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  GmSc   BPM
# ...

# %%
df.sort_values('Date', ascending=False)
# Out:
#       Rk     Age        Date   Tm Unnamed: 4  Opp Unnamed: 6  PTS  GS  MP  \
# 20    21  26-362  2022-02-16  DEN          @  GSW          W   35   1  34
# 123  124  26-360  2022-02-14  DEN        NaN  ORL          W   26   1  35
# 83    84  26-358  2022-02-12  DEN          @  TOR          W   28   1  35
# 157  158  26-357  2022-02-11  DEN          @  BOS          L   23   1  34
# 223  224  26-354  2022-02-08  DEN        NaN  NYK          W   21   1  30
# ..   ...     ...         ...  ...        ...  ...        ...  ...  ..  ..
# 480  481  20-260  2015-11-06  DEN          @  GSW          L    4   0  17
# 475  476  20-259  2015-11-05  DEN        NaN  UTA          L    5   0  18
# 427  428  20-255  2015-11-01  DEN          @  OKC          L    8   0  24
# 400  401  20-253  2015-10-30  DEN        NaN  MIN          L   10   0  18
# 493  494  20-251  2015-10-28  DEN          @  HOU          W    2   0   4
#
#      ...  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  GmSc   BPM
# ...

# %%
df.iloc[:, 7:33]
# Out:
#      PTS  GS  MP  FG  FGA    FG%  2P  2PA    2P%  3P  ...  ORB  DRB  TRB  AST  \
# 0     50   1  41  20   33  0.606  17   27  0.630   3  ...    1    7    8   12
# 1     49   1  41  16   25  0.640  13   20  0.650   3  ...    7    7   14   10
# 2     47   1  37  17   26  0.654  13   22  0.591   4  ...    3    9   12    5
# 3     47   1  37  16   25  0.640  12   17  0.706   4  ...    4    4    8    5
# 4     47   1  45  20   31  0.645  18   25  0.720   2  ...    7    8   15    8
# ..   ...  ..  ..  ..  ...    ...  ..  ...    ...  ..  ...  ...  ...  ...  ...
# 500    0   1   5   0    0    NaN   0    0    NaN   0  ...    0    1    1    1
# 501    0   1   4   0    0    NaN   0    0    NaN   0  ...    0    1    1    0
# 502    0   1  17   0    0    NaN   0    0    NaN   0  ...    0    5    5    3
# 503    0   0  26   0    3  0.000   0    3  0.000   0  ...    0    5    5    3
# 504    0   1  31   0    3  0.000   0    2  0.000   0  ...    0    9    9    7
#
# ...

# %%
this_game
# Out:
#    Age Pos  games played
# 0    3   c            22

# %%
df1
# Out:
#     Position                          Name + ID                    Name  \
# 0          C            Nikola Jokic (21388574)            Nikola Jokic
# 1         SF            Kevin Durant (21388576)            Kevin Durant
# 2         PF           DeMar DeRozan (21388579)           DeMar DeRozan
# 3         PG               Ja Morant (21388582)               Ja Morant
# 4         PG           Stephen Curry (21388585)           Stephen Curry
# ..       ...                                ...                     ...
# 328     PF/C   Juan Toscano-Anderson (21389677)   Juan Toscano-Anderson
# 329       PG           Chris Chiozza (21389681)           Chris Chiozza
# 330       PG            Nico Mannion (21389684)            Nico Mannion
# 331       SF            Axel Toupane (21389687)            Axel Toupane
# 332       PG  Quinndary Weatherspoon (21389690)  Quinndary Weatherspoon
#
#            ID Roster Position  Salary                      Game Info  \
# ...

# %%
f = df1.iloc[0,6].split(' ')[0].split('@')[1]

# %%
import pickle
load_file = open('Teams_emb.pickle', 'rb')
positions = pickle.load(load_file)

# %%
len(positions.keys())
# Out:
# 38

# %%
s = 'BKN'
positions
if s not in positions.keys():
    positions[s] = len(positions.keys())+1
    pickle.dump(positions, open('Teams_emb.pickle', 'wb'))
else:

# %%
load_file = open('Teams_emb.pickle', 'rb')
p = pickle.load(load_file)

# %%
if 'SG' in 'SG/G/UTIL':
    print('f')
# Out:
# f

# %%
load_file = open('Teams_emb.pickle', 'rb')
tms = pickle.load(load_file)

# %%
jj = [8, 9, 9, 9]
print(jj.pop(0))
# Out:
# 8

# %%
df = pd.read_csv('dks.csv')

# %%
tmlst = df['TeamAbbrev'].drop_duplicates().sort_values()

# %%
tmkeys = p.keys()
for i in tmlst:
    if i not in tmkeys:
        print(i)
# Out:
# PHX

# %%
p['BKN'] = 3
p['PHX'] = 29

# %%
p
# Out:
# {'ATL': 1,
#  'BOS': 2,
#  'BRK': 3,
#  'CHA': 4,
#  'CHH': 5,
#  'CHI': 6,
#  'CHO': 7,
#  'CLE': 8,
#  'DAL': 9,
#  'DEN': 10,
#  'DET': 11,
#  'GSW': 12,
#  'HOU': 13,
#  'IND': 14,
#  'LAC': 15,
#  'LAL': 16,
#  'MEM': 17,
#  'MIA': 18,
#  'MIL': 19,
#  'MIN': 20,
#  'NJN': 21,
#  'NOH': 22,
#  'NOK': 23,
#  'NOP': 24,
#  'NYK': 25,
#  'OKC': 26,
#  'ORL': 27,
#  'PHI': 28,
#  'PHO': 29,
#  'POR': 30,
#  'SAC': 31,
#  'SAS': 32,
#  'SEA': 33,
#  'TOR': 34,
#  'UTA': 35,
#  'VAN': 36,
#  'WAS': 37,
#  'WSB': 38,
#  'BKN': 3,
#  'PHX': 29}

# %%
pickle.dump(p, open('Teams_emb.pickle', 'wb'))

# %%
df4 = pd.read_csv('DKS3.csv')

# %%
df4
# Out:
#    Position                    Name + ID              Name        ID  \
# 0         C      Nikola Jokic (21390782)      Nikola Jokic  21390782
# 1        PG     Stephen Curry (21390670)     Stephen Curry  21390670
# 2        PG    Damian Lillard (21390686)    Damian Lillard  21390686
# 3      PF/C  Domantas Sabonis (21390802)  Domantas Sabonis  21390802
# 4         C      Jusuf Nurkic (21390780)      Jusuf Nurkic  21390780
# ..      ...                          ...               ...       ...
# 86       PF    Alen Smailagic (21390924)    Alen Smailagic  21390924
# 87       SG      Didi Louzada (21390927)      Didi Louzada  21390927
# 88       PG      Nico Mannion (21390941)      Nico Mannion  21390941
# 89    SG/SF       Moses Moody (21390952)       Moses Moody  21390952
# 90       SG      Keon Johnson (21390957)      Keon Johnson  21390957
#
#    Roster Position  Salary                      Game Info TeamAbbrev  \
# ...

# %%
import pickle
loads = open('temp x', 'rb')

# %%
x = pickle.load(loads)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25928/1467412936.py in <module>
# ----> 1 x = pickle.load(loads)
#
# EOFError: Ran out of input
